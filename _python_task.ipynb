# %%
import logging
logging.basicConfig(filename='loginfo4.log', level=logging.INFO, format='%(asctime)s %(levelname)s %(name)s  %(message)s')


# OOP program to reverse the string
class string_task:
    def string_reverse(self, ext_string):
        logging.info("This is program to reverse the entered string")
        self.ext_string=ext_string
        try:
            logging.info("we are checking for length of the string")
            if len(self.ext_string)==0:
                raise ValueError("empty string")
                logging.error("empty string")
            else:
                s=self.ext_string[::-1]
                logging.info(f"new string which is extracted is{s}")
        except Exception as e:
            logging.error(e)
            logging.exception(e)
mayank = string_task()
mayank.string_reverse("This is my first oop program")




#OOP program to print string with the gap of three letters
  def string_extract(self,ext_string):
            logging.info("WE are about to extact string from index one to index 300 with a jump of 3")
            self.ext_string = ext_string
            try:
                if len(self.ext_string) == 0:
                    raise ValueError("empty string")
                    logging.error("empty string")
                else:
                    str = self.ext_string[::3]
                    logging.info("Extracted string is %s: " , str)
                    return str
            except Exception as e:
                logging.exception(e)
mayank=string_task()
mayank.string_extract("This is my first oop program")


#OOP program to extract all the string from the list


class ext_string():
    def str_list(self,list_input,string_collection):
        logging.info("we are creating the function to extract string form the list")
        self.list_input=list_input
        self.strr=string_collection
        try:
            logging.info("we are calculating the length of the list")
            if len(self.list_input)==0:
                raise  ValueError("list is empty")
                logging.info("list provided is empty")
            else:
                for i in self.list_input:
                    if type(i)==str:
                        string_collection=(i)
                logging.info(f"all the strings from the list is {string_collection}")
                return string_collection


        except Exception as e:
            logging.exception(e)

mayank=ext_string()
mayank.str_list([1,3,4,"python",3.4],[])


#OOP program to extract all the values of the dict from the list



class string_task:
    def extact_valuelist(self, list1_value):
        logging.info("we are about ectract the list")
        self.list1_value = list1_value
        try:
            if len(list1_value) == 0:
                raise ValueError("list is empty  ")
                logging.error("lit is empty")
            else:
                l = []
                for i in list1_value:
                    if type(i) == dict:
                        for k in i:
                            logging.info("the value in list is %s ", i[k])
                            l.append(i[k])
            return l
        except Exception as e:
            logging.exception(e)

mayank=string_task()
mayank.extact_valuelist([1,2,"mayank",{1:"football",2:"cricket"},2.4])


#OOP program                                                                                      


#extract all the integer fron the list
      
class extract:
    def ext_allint_list(self, list1):
        logging.info("we are about extract the list")
        self.list1 = list1
        try:
            if len(list1) == 0:
                raise ValueError("list is empty  ")
                logging.error("list is empty")
            else:
                l = []
                for i in self.list1:
                    if type(i) == tuple or type(i) == list or type(i) == set:
                        for j in i:
                            if type(j) == int:
                                logging.info("the int value is %s ", j)
                                l.append(j)
                    if type(i) == dict:
                        logging.info("the value dict")
                        for k, v in i.items():
                            if type(k) == int or type(v) == int:
                                l.append(k)
                                l.append(v)
            logging.info(f"all the integers are{l}")

        except Exception as e:
            logging.exception(e)

mayank=extract()
mayank.ext_allint_list([[1,3,"harry",7],(1,7,"potter")])



#extract all sum of the integer fron the list
         
class count_int():
    def ext_sum_list(self, list1):
        logging.info("we are about ectract the list")
        self.list1 = list1
        try:
            if len(list1) == 0:
                raise ValueError("list is empty  ")
                logging.error("list is empty")
            else:
                l = []
                for i in self.list1:
                    if type(i) == tuple or type(i) == list or type(i) == set:
                        for j in i:
                            if type(j) == int:
                                logging.info("the int value is %s ", j)
                                l.append(j)
                    if type(i) == dict:
                        logging.info("the value dict")
                        for k, v in i.items():
                            if type(k) == int or type(v) == int:
                                l.append(k)
                                l.append(v)
            logging.info(f"sum is {sum(l)}")
            return sum(l)
        except Exception as e:
            logging.exception(e)


mayank=count_int()
mayank.ext_sum_list([[1,2,3,"harry"],(1,2,3,"potter")])

     
#extract number of occurance of indiviual number  fron the list
        def ext_occ_num(self, list1):
            logging.info("we are about ectract the list")
            self.list1 = list1
            try:
                if len(list1)== 0:
                    raise ValueError("list is empty  ")
                    logging.error("list is empty")
                else:
                    l = []
                    for i in list1:
                        if type(i) == tuple or type(i) == list or type(i) == set:
                            for j in i:
                                if type(j) == int:
                                    logging.info("the int value is %s ", j)
                                    l.append(j)
                        if type(i) == dict:
                            logging.info("the value dict")
                            for k, v in i.items():
                                if type(k) == int or type(v) == int:
                                    logging.info("the int value is %s ", j)
                                    l.append(k)
                                    l.append(v)
                count ={}
                for b in l:
                    if b in count:
                        count[b] = l.count(b)
                    else:
                        count[b] = l.count(b)
                return count
            except Exception as e:
                logging.exception(e)
                               l.append(v)
                return sum(l)
            except Exception as e:
                logging.exception(e)
